# %%
import re
import lda
import json
import spacy
import warnings
import numpy as np
import pandas as pd
import pyLDAvis.sklearn

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.metrics import pairwise_distances
from nltk.corpus import stopwords

def tokenize(string):
    doc = model(string)
    words = []
    for w in doc:
        if w.pos_ not in discard and len(w.lemma_) > 1:
            words.append(w.lemma_ + "_" + w.pos_)
    return words

stopwords = stopwords.words('english')
warnings.simplefilter('ignore')
reg = re.compile(r'[0-9]+')
discard = {'PUNCT', 'SPACE', 'SYM', 'NUM', 'X', 'PRON', 'DET', 'PART', 'ADP'}

pyLDAvis.enable_notebook()
model = spacy.load('en')

# %%
data = fetch_20newsgroups(categories=['rec.autos','rec.motorcycles', 'sci.crypt', 
                                      'sci.electronics','sci.med','sci.space','talk.politics.guns',
                                      'talk.politics.mideast','talk.religion.misc'])

data.data = [reg.sub("", i) for i in data.data]

vectorizer = CountVectorizer(stop_words=stopwords, max_df=0.3, min_df=10, lowercase=False, tokenizer=tokenize)
vectorized_data = vectorizer.fit_transform(data.data)

# %%
model = lda.LDA(n_topics=20, n_iter=2500)
transformed_data = model.fit_transform(vectorized_data)
# Out:
# INFO:lda:n_documents: 5052
# INFO:lda:vocab_size: 8074
# INFO:lda:n_words: 667023
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 2500
# INFO:lda:<0> log likelihood: -8075724
# INFO:lda:<10> log likelihood: -6085954
# INFO:lda:<20> log likelihood: -5806069
# INFO:lda:<30> log likelihood: -5708973
# INFO:lda:<40> log likelihood: -5652210
# INFO:lda:<50> log likelihood: -5616562
# INFO:lda:<60> log likelihood: -5591478
# INFO:lda:<70> log likelihood: -5571757
# INFO:lda:<80> log likelihood: -5558738
# INFO:lda:<90> log likelihood: -5547197
# INFO:lda:<100> log likelihood: -5538730
# INFO:lda:<110> log likelihood: -5530909
# INFO:lda:<120> log likelihood: -5523478
# INFO:lda:<130> log likelihood: -5519177
# INFO:lda:<140> log likelihood: -5510194
# INFO:lda:<150> log likelihood: -5503387
# INFO:lda:<160> log likelihood: -5501162
# INFO:lda:<170> log likelihood: -5498268
# INFO:lda:<180> log likelihood: -5493835
# INFO:lda:<190> log likelihood: -5491690
# INFO:lda:<200> log likelihood: -5488625
# INFO:lda:<210> log likelihood: -5487304
# INFO:lda:<220> log likelihood: -5483520
# INFO:lda:<230> log likelihood: -5480188
# INFO:lda:<240> log likelihood: -5478927
# INFO:lda:<250> log likelihood: -5479055
# INFO:lda:<260> log likelihood: -5478049
# INFO:lda:<270> log likelihood: -5477309
# INFO:lda:<280> log likelihood: -5475286
# INFO:lda:<290> log likelihood: -5473202
# INFO:lda:<300> log likelihood: -5474272
# INFO:lda:<310> log likelihood: -5474332
# INFO:lda:<320> log likelihood: -5471875
# INFO:lda:<330> log likelihood: -5473099
# INFO:lda:<340> log likelihood: -5472998
# INFO:lda:<350> log likelihood: -5471135
# INFO:lda:<360> log likelihood: -5472021
# INFO:lda:<370> log likelihood: -5470562
# INFO:lda:<380> log likelihood: -5468947
# INFO:lda:<390> log likelihood: -5467827
# INFO:lda:<400> log likelihood: -5467640
# INFO:lda:<410> log likelihood: -5467562
# INFO:lda:<420> log likelihood: -5467630
# INFO:lda:<430> log likelihood: -5469179
# INFO:lda:<440> log likelihood: -5465689
# INFO:lda:<450> log likelihood: -5468297
# INFO:lda:<460> log likelihood: -5466988
# INFO:lda:<470> log likelihood: -5466041
# INFO:lda:<480> log likelihood: -5465873
# INFO:lda:<490> log likelihood: -5464290
# INFO:lda:<500> log likelihood: -5464594
# INFO:lda:<510> log likelihood: -5463528
# INFO:lda:<520> log likelihood: -5464717
# INFO:lda:<530> log likelihood: -5464658
# INFO:lda:<540> log likelihood: -5463442
# INFO:lda:<550> log likelihood: -5463068
# INFO:lda:<560> log likelihood: -5463521
# INFO:lda:<570> log likelihood: -5462952
# INFO:lda:<580> log likelihood: -5461451
# INFO:lda:<590> log likelihood: -5463714
# INFO:lda:<600> log likelihood: -5463289
# INFO:lda:<610> log likelihood: -5463107
# INFO:lda:<620> log likelihood: -5463618
# INFO:lda:<630> log likelihood: -5463942
# INFO:lda:<640> log likelihood: -5462901
# INFO:lda:<650> log likelihood: -5462037
# INFO:lda:<660> log likelihood: -5463560
# INFO:lda:<670> log likelihood: -5462449
# INFO:lda:<680> log likelihood: -5462371
# INFO:lda:<690> log likelihood: -5462658
# INFO:lda:<700> log likelihood: -5463640
# INFO:lda:<710> log likelihood: -5464497
# INFO:lda:<720> log likelihood: -5463914
# INFO:lda:<730> log likelihood: -5465432
# INFO:lda:<740> log likelihood: -5463590
# INFO:lda:<750> log likelihood: -5465180
# INFO:lda:<760> log likelihood: -5464323
# INFO:lda:<770> log likelihood: -5464097
# INFO:lda:<780> log likelihood: -5464338
# INFO:lda:<790> log likelihood: -5462597
# INFO:lda:<800> log likelihood: -5462464
# INFO:lda:<810> log likelihood: -5463277
# INFO:lda:<820> log likelihood: -5462698
# INFO:lda:<830> log likelihood: -5462420
# INFO:lda:<840> log likelihood: -5464978
# INFO:lda:<850> log likelihood: -5461950
# INFO:lda:<860> log likelihood: -5463003
# INFO:lda:<870> log likelihood: -5462151
# INFO:lda:<880> log likelihood: -5464074
# INFO:lda:<890> log likelihood: -5462763
# INFO:lda:<900> log likelihood: -5461848
# INFO:lda:<910> log likelihood: -5462224
# INFO:lda:<920> log likelihood: -5465677
# INFO:lda:<930> log likelihood: -5463417
# INFO:lda:<940> log likelihood: -5462832
# INFO:lda:<950> log likelihood: -5463317
# INFO:lda:<960> log likelihood: -5463289
# INFO:lda:<970> log likelihood: -5463913
# INFO:lda:<980> log likelihood: -5462329
# INFO:lda:<990> log likelihood: -5463625
# INFO:lda:<1000> log likelihood: -5464681
# INFO:lda:<1010> log likelihood: -5462651
# INFO:lda:<1020> log likelihood: -5462742
# INFO:lda:<1030> log likelihood: -5463361
# INFO:lda:<1040> log likelihood: -5462156
# INFO:lda:<1050> log likelihood: -5462150
# INFO:lda:<1060> log likelihood: -5463729
# INFO:lda:<1070> log likelihood: -5461078
# INFO:lda:<1080> log likelihood: -5461782
# INFO:lda:<1090> log likelihood: -5462609
# INFO:lda:<1100> log likelihood: -5462191
# INFO:lda:<1110> log likelihood: -5461725
# INFO:lda:<1120> log likelihood: -5460572
# INFO:lda:<1130> log likelihood: -5461871
# INFO:lda:<1140> log likelihood: -5460973
# INFO:lda:<1150> log likelihood: -5461155
# INFO:lda:<1160> log likelihood: -5461131
# INFO:lda:<1170> log likelihood: -5463076
# INFO:lda:<1180> log likelihood: -5461935
# INFO:lda:<1190> log likelihood: -5462362
# INFO:lda:<1200> log likelihood: -5462110
# INFO:lda:<1210> log likelihood: -5460810
# INFO:lda:<1220> log likelihood: -5460234
# INFO:lda:<1230> log likelihood: -5460736
# INFO:lda:<1240> log likelihood: -5461680
# INFO:lda:<1250> log likelihood: -5461361
# INFO:lda:<1260> log likelihood: -5460826
# INFO:lda:<1270> log likelihood: -5462368
# INFO:lda:<1280> log likelihood: -5461586
# INFO:lda:<1290> log likelihood: -5461035
# INFO:lda:<1300> log likelihood: -5461844
# INFO:lda:<1310> log likelihood: -5462000
# INFO:lda:<1320> log likelihood: -5462197
# INFO:lda:<1330> log likelihood: -5461878
# INFO:lda:<1340> log likelihood: -5461326
# INFO:lda:<1350> log likelihood: -5461971
# INFO:lda:<1360> log likelihood: -5461505
# INFO:lda:<1370> log likelihood: -5461036
# INFO:lda:<1380> log likelihood: -5462211
# INFO:lda:<1390> log likelihood: -5460901
# INFO:lda:<1400> log likelihood: -5460741
# INFO:lda:<1410> log likelihood: -5461528
# INFO:lda:<1420> log likelihood: -5461258
# INFO:lda:<1430> log likelihood: -5462108
# INFO:lda:<1440> log likelihood: -5463173
# INFO:lda:<1450> log likelihood: -5462274
# INFO:lda:<1460> log likelihood: -5463348
# INFO:lda:<1470> log likelihood: -5461047
# INFO:lda:<1480> log likelihood: -5461650
# INFO:lda:<1490> log likelihood: -5461188
# INFO:lda:<1500> log likelihood: -5459567
# INFO:lda:<1510> log likelihood: -5460272
# INFO:lda:<1520> log likelihood: -5460669
# INFO:lda:<1530> log likelihood: -5461284
# INFO:lda:<1540> log likelihood: -5462361
# INFO:lda:<1550> log likelihood: -5461911
# INFO:lda:<1560> log likelihood: -5461170
# INFO:lda:<1570> log likelihood: -5462954
# INFO:lda:<1580> log likelihood: -5461416
# INFO:lda:<1590> log likelihood: -5461881
# INFO:lda:<1600> log likelihood: -5461403
# INFO:lda:<1610> log likelihood: -5462197
# INFO:lda:<1620> log likelihood: -5461076
# INFO:lda:<1630> log likelihood: -5459162
# INFO:lda:<1640> log likelihood: -5459053
# INFO:lda:<1650> log likelihood: -5459220
# INFO:lda:<1660> log likelihood: -5462292
# INFO:lda:<1670> log likelihood: -5461312
# INFO:lda:<1680> log likelihood: -5461829
# INFO:lda:<1690> log likelihood: -5461644
# INFO:lda:<1700> log likelihood: -5461809
# INFO:lda:<1710> log likelihood: -5461535
# INFO:lda:<1720> log likelihood: -5460079
# INFO:lda:<1730> log likelihood: -5460291
# INFO:lda:<1740> log likelihood: -5462154
# INFO:lda:<1750> log likelihood: -5461182
# INFO:lda:<1760> log likelihood: -5460627
# INFO:lda:<1770> log likelihood: -5460251
# INFO:lda:<1780> log likelihood: -5461094
# INFO:lda:<1790> log likelihood: -5461580
# INFO:lda:<1800> log likelihood: -5462416
# INFO:lda:<1810> log likelihood: -5461297
# INFO:lda:<1820> log likelihood: -5461173
# INFO:lda:<1830> log likelihood: -5461935
# INFO:lda:<1840> log likelihood: -5463433
# INFO:lda:<1850> log likelihood: -5461931
# INFO:lda:<1860> log likelihood: -5459700
# INFO:lda:<1870> log likelihood: -5461056
# INFO:lda:<1880> log likelihood: -5462683
# INFO:lda:<1890> log likelihood: -5461881
# INFO:lda:<1900> log likelihood: -5461630
# INFO:lda:<1910> log likelihood: -5463521
# INFO:lda:<1920> log likelihood: -5462821
# INFO:lda:<1930> log likelihood: -5460643
# INFO:lda:<1940> log likelihood: -5463777
# INFO:lda:<1950> log likelihood: -5461608
# INFO:lda:<1960> log likelihood: -5461409
# INFO:lda:<1970> log likelihood: -5461641
# INFO:lda:<1980> log likelihood: -5461789
# INFO:lda:<1990> log likelihood: -5462713
# INFO:lda:<2000> log likelihood: -5459852
# INFO:lda:<2010> log likelihood: -5460463
# INFO:lda:<2020> log likelihood: -5461173
# INFO:lda:<2030> log likelihood: -5461748
# INFO:lda:<2040> log likelihood: -5460525
# INFO:lda:<2050> log likelihood: -5461119
# INFO:lda:<2060> log likelihood: -5462224
# INFO:lda:<2070> log likelihood: -5459958
# INFO:lda:<2080> log likelihood: -5459628
# INFO:lda:<2090> log likelihood: -5460618
# INFO:lda:<2100> log likelihood: -5459756
# INFO:lda:<2110> log likelihood: -5460554
# INFO:lda:<2120> log likelihood: -5459299
# INFO:lda:<2130> log likelihood: -5461376
# INFO:lda:<2140> log likelihood: -5461082
# INFO:lda:<2150> log likelihood: -5462392
# INFO:lda:<2160> log likelihood: -5460230
# INFO:lda:<2170> log likelihood: -5462199
# INFO:lda:<2180> log likelihood: -5461663
# INFO:lda:<2190> log likelihood: -5460601
# INFO:lda:<2200> log likelihood: -5461062
# INFO:lda:<2210> log likelihood: -5459802
# INFO:lda:<2220> log likelihood: -5459434
# INFO:lda:<2230> log likelihood: -5460776
# INFO:lda:<2240> log likelihood: -5458779
# INFO:lda:<2250> log likelihood: -5458142
# INFO:lda:<2260> log likelihood: -5458984
# INFO:lda:<2270> log likelihood: -5461118
# INFO:lda:<2280> log likelihood: -5460100
# INFO:lda:<2290> log likelihood: -5459978
# INFO:lda:<2300> log likelihood: -5460258
# INFO:lda:<2310> log likelihood: -5459895
# INFO:lda:<2320> log likelihood: -5459531
# INFO:lda:<2330> log likelihood: -5458822
# INFO:lda:<2340> log likelihood: -5459950
# INFO:lda:<2350> log likelihood: -5459352
# INFO:lda:<2360> log likelihood: -5458372
# INFO:lda:<2370> log likelihood: -5459669
# INFO:lda:<2380> log likelihood: -5458689
# INFO:lda:<2390> log likelihood: -5458885
# INFO:lda:<2400> log likelihood: -5458630
# INFO:lda:<2410> log likelihood: -5458473
# INFO:lda:<2420> log likelihood: -5459788
# INFO:lda:<2430> log likelihood: -5460050
# INFO:lda:<2440> log likelihood: -5458179
# INFO:lda:<2450> log likelihood: -5458671
# INFO:lda:<2460> log likelihood: -5459796
# INFO:lda:<2470> log likelihood: -5459259
# INFO:lda:<2480> log likelihood: -5459993
# INFO:lda:<2490> log likelihood: -5459469
# INFO:lda:<2499> log likelihood: -5460682

# %%
pylda = pyLDAvis.sklearn.prepare(model, vectorized_data, vectorizer, mds='mmds')
#pylda

# %%
top = {}
for i in range(1, 11):
    top[i] = pylda.token_table[pylda.token_table['Topic'] == i].sort_values('Freq', ascending=False)
    
for i in range(1,11):
    print('Topic:', i)
    print('Top words:', list(top[i]['Term'].head(10)))
    print()
# Out:
# Topic: 1
# Top words: ['quite_ADJ', 'logical_ADJ', 'influence_NOUN', 'confuse_VERB', 'convince_VERB', 'whatsoever_ADV', 'nevertheless_ADV', 'fashion_NOUN', 'inherently_ADV', 'accusation_NOUN']
#
# Topic: 2
# Top words: ['smash_VERB', 'scratch_VERB', 'upstairs_ADV', 'accounts_PROPN', 'violations_PROPN', 'azerbaijanis_PROPN', 'yerevan_PROPN', 'hall_NOUN', 'apartment_NOUN', 'dseg_PROPN']
#
# Topic: 3
# Top words: ['annual_PROPN', 'isbn_PROPN', 'convention_PROPN', 'commission_PROPN', 'participation_NOUN', 'chair_PROPN', 'transportation_PROPN', 'assembly_PROPN', 'staff_PROPN', 'editor_PROPN']
#
# Topic: 4
# Top words: ['crypto_ADJ', 'crypto_ADV', 'cellular_ADJ', 'denning_PROPN', 'toal_PROPN', 'decrypt_VERB', 'escrow_VERB', 'encryption_NOUN', 'clipper_NOUN', 'encryption_PROPN']
#
# Topic: 5
# Top words: ['fm_PROPN', 'sat_PROPN', 'simms_PROPN', 'bulletin_PROPN', 'compuserve_PROPN', 'williams_PROPN', 'brookline_PROPN', 'barry_PROPN', 'mailing_PROPN', 'babb_PROPN']
#
# Topic: 6
# Top words: ['odometer_NOUN', 'ak@yfn.ysu.edu_PROPN', 'trunk_NOUN', 'wagon_NOUN', 'clutch_NOUN', 'nissan_PROPN', 'dodge_PROPN', 'torque_NOUN', 'callison_PROPN', 'integra_PROPN']
#
# Topic: 7
# Top words: ['mhz_NOUN', 'relay_NOUN', 'wire_NOUN', 'volt_NOUN', 'printer_NOUN', 'fuse_NOUN', 'capacitor_NOUN', 'resistor_NOUN', 'covington_PROPN', 'prong_NOUN']
#
# Topic: 8
# Top words: ['payload_NOUN', 'orbital_ADJ', 'jet_PROPN', 'venus_PROPN', 'baalke_PROPN', 'baalke@kelvin.jpl.nasa.gov_PROPN', 'telescope_PROPN', 'nsmca@aurora.alaska.edu_NOUN', 'galileo_PROPN', 'comet_PROPN']
#
# Topic: 9
# Top words: ['pem_PROPN', 'ripem_PROPN', 'ftp_NOUN', 'ftp_PROPN', 'patent_NOUN', 'password_NOUN', 'pc_PROPN', 'news.answer_NOUN', 'sci.crypt_ADJ', 'hash_NOUN']
#
# Topic: 10
# Top words: ['truely_ADV', 'pathetic_ADJ', 'stoop_VERB', 'deal_PROPN', 'workable_ADJ', 'estate_NOUN', 'recreational_ADJ', 'overpass_NOUN', 'fuck_NOUN', 'jeffry_PROPN']

# %%
distances = pairwise_distances(transformed_data, metric='cosine')
np.fill_diagonal(distances, np.inf)
distances
# Out:
# array([[       inf, 0.96506414, 0.74076223, ..., 0.6835988 , 0.74007829,
#         0.73183347],
#        [0.96506414,        inf, 0.93861441, ..., 0.96581955, 0.80646567,
#         0.96829524],
#        [0.74076223, 0.93861441,        inf, ..., 0.89028857, 0.88864282,
#         0.91518388],
#        ...,
#        [0.6835988 , 0.96581955, 0.89028857, ...,        inf, 0.70277978,
#         0.63332169],
#        [0.74007829, 0.80646567, 0.88864282, ..., 0.70277978,        inf,
#         0.68347683],
#        [0.73183347, 0.96829524, 0.91518388, ..., 0.63332169, 0.68347683,
#                inf]])

# %%
score = np.mean(data.target[np.argpartition(distances, 99)[:,:100]] == data.target[:,None])
print('Top 100 mAP is {}'.format(score))

# %%
scores = {}
for i in range(len(distances)):
    if data.target[i] not in scores:
        scores[data.target[i]] = []
    scores[data.target[i]].append(np.mean(data.target[np.argsort(distances[i])[:100]] == data.target[i]))
    
for i in scores.keys():
    scores[i] = np.mean(scores[i])
    
dataframe = pd.DataFrame(list(scores.values()), index=scores.keys())
dataframe.index = [data.target_names[i] for i in dataframe.index]
dataframe.columns = ['Top 100 AP']
dataframe.sort_values('Top 100 AP', ascending=False)
# Out:
#                        Top 100 AP
# talk.politics.mideast    0.825762
# sci.crypt                0.797966
# rec.motorcycles          0.775000
# sci.electronics          0.733384
# sci.space                0.729933
# sci.med                  0.694327
# talk.politics.guns       0.686722
# rec.autos                0.686684
# talk.religion.misc       0.592440
# talk.politics.misc       0.467376

# %%
data.target[0]
# Out:
# 5

# %%
data.target[np.argsort(distances[0])[1:101]] == 5
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
np.mean(data.target[np.argsort(distances[0])[1:101]] == 5)
# Out:
# 0.99
