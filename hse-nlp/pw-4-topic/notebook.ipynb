# %%
import pandas as pd
import json
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('russian')

# %%
data = []
with open('../hw-1-parser/output/rambler-news.json') as file:
    for line in file:
        data.append(json.loads(line))

data = pd.DataFrame(data)

# %%
data.head()
# Out:
#    category                                               link  \
# 0  politics  https://news.rambler.ru/politics/39054690-push...
# 1  politics  https://news.rambler.ru/world/39054594-na-kipr...
# 2  politics  https://news.rambler.ru/politics/39054551-neme...
# 3  politics  https://news.rambler.ru/conflicts/39054513-pen...
# 4  politics  https://news.rambler.ru/middleeast/39054357-v-...
#
#                                                 text  \
# 0  Член Совета Федерации РФ Алексей Пушков назвал...
# 1  На Кипре пройдет второй тур президентских выбо...
# 2  Депутаты делегации из Северной Рейн-Вестфалии,...
# 3  РИА НОВОСТИ. США НЕ СНАБЖАЛИ СВОИХ СОЮЗНИКОВ П...
# 4  Инцидент с российским самолетом Су-25 в Сирии ...
#
#                                                title
# 0  Пушков назвал требования Украины лишить РФ пра...
# 1     На Кипре пройдет второй тур выборов президента
# 2  Немецкий депутат поставил на место Климкина в ...
# 3  Пентагон: США не снабжали союзников по коалици...
# 4  Депутат ГД призвал расследовать, откуда у сири...

# %%
data['category'].unique()
# Out:
# array(['politics', 'economics', 'incidents', 'realty'], dtype=object)

# %%
vectorizer = CountVectorizer(stop_words=stopwords)

X = vectorizer.fit_transform(data['text'])
y = data['category']

# %%
lda = LatentDirichletAllocation(n_components=10)
lda.fit(X)
pyLDAvis.sklearn.prepare(lda, X, vectorizer)
# Out:
# /Users/lxdv/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:536: DeprecationWarning: The default value for 'learning_method' will be changed from 'online' to 'batch' in the release 0.20. This warning was introduced in 0.18.
#   DeprecationWarning)
# /Users/lxdv/anaconda3/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 6      37.794063        1       1  0.208453  0.037888
# 8      29.209305        1       2  0.244332 -0.075143
# 2      11.021991        1       3 -0.056070  0.298187
# 0       8.657621        1       4  0.057832  0.018720
# 9       5.915135        1       5  0.027651 -0.004807
# 4       3.583640        1       6 -0.089403 -0.063152
# 1       1.632453        1       7 -0.074687 -0.066867
# 7       1.022380        1       8 -0.121105 -0.058404
# 3       0.610408        1       9 -0.102434 -0.043978
# 5       0.553005        1      10 -0.094568 -0.042443, topic_info=      Category         Freq            Term        Total  loglift  logprob
# term
# 16167  Default   813.000000            млрд   813.000000  30.0000  30.0000
# 32949  Default   649.000000             сша   649.000000  29.0000  29.0000
# 29008  Default   948.000000          россии   948.000000  28.0000  28.0000
# 289    Default   868.000000            2017   868.000000  27.0000  27.0000
# 25230  Default   221.000000      президента   221.000000  26.0000  26.0000
# 29102  Default  1052.000000          рублей  1052.000000  25.0000  25.0000
# 15943  Default   343.000000       миллиарда   343.000000  24.0000  24.0000
# 7152   Default   836.000000            году   836.000000  23.0000  23.0000
# 36332  Default   104.000000             цик   104.000000  22.0000  22.0000
# 29208  Default   512.000000              рф   512.000000  21.0000  21.0000
# 29041  Default   249.000000            рост   249.000000  20.0000  20.0000
# 290    Default   553.000000            2018   553.000000  19.0000  19.0000
# 6034   Default   113.000000          выборы   113.000000  18.0000  18.0000
# 25336  Default   324.000000           пресс   324.000000  17.0000  17.0000
# 28512  Default   159.000000      результате   159.000000  16.0000  16.0000
# 34080  Default   374.000000             тыс   374.000000  15.0000  15.0000
# 18934  Default   357.000000         области   357.000000  14.0000  14.0000
# 2505   Default    72.000000           акции    72.000000  13.0000  13.0000
# 34878  Default   105.000000          уровне   105.000000  12.0000  12.0000
# 8896   Default   269.000000        долларов   269.000000  11.0000  11.0000
# 37413  Default   758.000000             это   758.000000  10.0000  10.0000
# 37633  Default   315.000000          января   315.000000   9.0000   9.0000
# 18377  Default    82.000000           нефть    82.000000   8.0000   8.0000
# 7842   Default   266.000000          данным   266.000000   7.0000   7.0000
# 12348  Default   212.000000          итогам   212.000000   6.0000   6.0000
# 7132   Default  1432.000000            года  1432.000000   5.0000   5.0000
# 175    Default   145.000000              18   145.000000   4.0000   4.0000
# 23647  Default    94.000000         полиции    94.000000   3.0000   3.0000
# 29236  Default   148.000000           рынке   148.000000   2.0000   2.0000
# 8147   Default   131.000000            дело   131.000000   1.0000   1.0000
# ...        ...          ...             ...          ...      ...      ...
# 35702  Topic10     1.073008  фондохранилища     1.730195   4.7198  -6.9988
# 15883  Topic10     1.072902   мехстройтранс     1.730433   4.7196  -6.9989
# 10833  Topic10     1.009686         затвора     1.650551   4.7061  -7.0596
# 3987   Topic10     0.975865     браконьеров     1.621880   4.6895  -7.0937
# 14981  Topic10     0.972890           лосей     1.629591   4.6817  -7.0967
# 35974  Topic10     1.023462       хаспалаев     1.734844   4.6698  -7.0461
# 16157  Topic10     0.886151              мл     1.522061   4.6566  -7.1901
# 1504   Topic10     0.881420          living     1.519724   4.6528  -7.1955
# 1215   Topic10     0.880871        downtown     1.521200   4.6512  -7.1961
# 1075   Topic10     0.880845        business     1.521180   4.6512  -7.1961
# 9325   Topic10     0.880431           дубае     1.522509   4.6499  -7.1966
# 29496  Topic10     0.884088         сахалин     1.530118   4.6490  -7.1924
# 33864  Topic10     0.879497        трескова     1.524629   4.6474  -7.1977
# 16511  Topic10     0.879444      мостотрест     1.524572   4.6474  -7.1977
# 9328   Topic10     0.875142           дубна     1.536247   4.6348  -7.2026
# 16403  Topic10     0.832602      монолитных     1.468688   4.6300  -7.2524
# 35504  Topic10     0.830150         федотов     1.465136   4.6295  -7.2554
# 944    Topic10     0.830141            acmg     1.465291   4.6293  -7.2554
# 1645   Topic10     0.830075        officiel     1.465275   4.6293  -7.2555
# 23846  Topic10     0.785473        полякова     1.435426   4.5946  -7.3107
# 10832  Topic10     0.763799          затвор     1.401662   4.5904  -7.3387
# 15412  Topic10     1.806899           масло     3.556221   4.5205  -6.4776
# 19892  Topic10     1.537614          оленей     4.481652   4.1278  -6.6390
# 7743   Topic10     0.985730             гэс     2.538963   4.2514  -7.0836
# 11454  Topic10     1.076438    изготовления     5.589675   3.5503  -6.9956
# 31625  Topic10     1.339102           союза    44.944119   1.6841  -6.7772
# 1002   Topic10     0.890664           apple     2.446910   4.1869  -7.1850
# 20251  Topic10     0.955270     организации    95.599461   0.5916  -7.1150
# 18247  Topic10     0.929136       несколько   111.856810   0.4068  -7.1427
# 14982  Topic10     0.884896            лося     2.729013   4.0713  -7.1915
#
# [603 rows x 6 columns], token_table=       Topic      Freq          Term
# term
# 0          2  0.113034            00
# 0          3  0.452137            00
# 0          5  0.037678            00
# 0          6  0.207230            00
# 0          7  0.169551            00
# 40         1  0.329229            10
# 40         2  0.508228            10
# 40         3  0.073517            10
# 40         4  0.025571            10
# 40         5  0.044750            10
# 40         6  0.012786            10
# 40         7  0.009589            10
# 175        1  0.316543            18
# 175        2  0.206441            18
# 175        4  0.041288            18
# 175        5  0.371594            18
# 175        6  0.041288            18
# 175        7  0.013763            18
# 201        8  0.791671          1918
# 203        8  0.788822          1920
# 215        1  0.088515          1943
# 215        6  0.796639          1943
# 268        1  0.491325            20
# 268        2  0.274228            20
# 268        3  0.171392            20
# 268        4  0.017139            20
# 268        7  0.039992            20
# 287        1  0.234600          2016
# 287        2  0.734268          2016
# 287        4  0.024374          2016
# ...      ...       ...           ...
# 36813      6  0.919081           шер
# 37132      1  0.976198  эксплуатацию
# 37256      5  0.963080          элла
# 37413      1  0.589197           это
# 37413      2  0.283395           это
# 37413      3  0.002636           это
# 37413      4  0.068542           это
# 37413      5  0.035589           это
# 37413      6  0.017135           это
# 37413      8  0.002636           это
# 37487      7  0.864373           юит
# 37546      8  0.909931       юшенков
# 37560      5  0.985016     явлинский
# 37564      1  0.389711      является
# 37564      2  0.314283      является
# 37564      3  0.056571      является
# 37564      4  0.125713      является
# 37564      5  0.050285      является
# 37564      6  0.062857      является
# 37581      4  0.939647      ядерного
# 37582      1  0.050327       ядерной
# 37582      4  0.905885       ядерной
# 37587      1  0.070903       ядерных
# 37587      4  0.709034       ядерных
# 37587      8  0.212710       ядерных
# 37633      1  0.332784        января
# 37633      2  0.370817        января
# 37633      3  0.114098        января
# 37633      4  0.028524        января
# 37633      5  0.155299        января
#
# [1060 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[7, 9, 3, 1, 10, 5, 2, 8, 4, 6])
